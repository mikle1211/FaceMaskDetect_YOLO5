# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd yolov5
 
import torch
from IPython.display import Image, clear_output  # to display images
from utils.downloads import gdrive_download  # to download models/datasets

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/yolo/data
# Out:
# classes.txt		datadownloadv4.ipynb  FaceMaskDataset.zip
# convert_annotations.py	datadownloadv5.ipynb  plate.zip

# %%
# copy over both datasets into the root directory of the Colab VM (comment out test.zip if you are not using a validation dataset)
# !cp /content/drive/MyDrive/yolo/data/plate.zip /content
# !cp /content/drive/MyDrive/yolo/data/FaceMaskDataset.zip /content

# %%
# unzip the datasets and their contents so that they are now in /content/darknet/data/ folder
# !unzip /content/plate.zip -d /content/
# !unzip /content/FaceMaskDataset.zip -d /content/
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: /content/FaceMaskDataset/images/val/4558.jpg
#   inflating: /content/FaceMaskDataset/images/val/4559.jpg
#   inflating: /content/FaceMaskDataset/images/val/4560.jpg
#   inflating: /content/FaceMaskDataset/images/val/4561.jpg
#   inflating: /content/FaceMaskDataset/images/val/4562.jpg
#   inflating: /content/FaceMaskDataset/images/val/4563.jpg
#   inflating: /content/FaceMaskDataset/images/val/4564.jpg
#   inflating: /content/FaceMaskDataset/images/val/4565.jpg
#   inflating: /content/FaceMaskDataset/images/val/4566.jpg
#   inflating: /content/FaceMaskDataset/images/val/4567.jpg
#   inflating: /content/FaceMaskDataset/images/val/4568.jpg
#   inflating: /content/FaceMaskDataset/images/val/4569.jpg
#   inflating: /content/FaceMaskDataset/images/val/4570.jpg
#   inflating: /content/FaceMaskDataset/images/val/4571.jpg
#   inflating: /content/FaceMaskDataset/images/val/4572.jpg
#   inflating: /content/FaceMaskDataset/images/val/4573.jpg
# ...

# %%
# !python train.py --img 256 --batch 32 --epochs 20 --hyp /content/drive/MyDrive/yolo/yolov5/hyp.custom.yaml  --data /content/drive/MyDrive/yolo/yolov5/mask.yaml --cfg /content/drive/MyDrive/yolo/yolov5/yolov5x.yaml --weights yolov5x.pt --name ''
# Out:
# ...
# train: weights=yolov5x.pt, cfg=/content/drive/MyDrive/yolo/yolov5/yolov5x.yaml, data=/content/drive/MyDrive/yolo/yolov5/mask.yaml, hyp=/content/drive/MyDrive/yolo/yolov5/hyp.custom.yaml, epochs=10, batch_size=32, imgsz=256, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-188-g80473a6 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !cp 'runs/train/weights/best.pt' /content/drive/MyDrive/yolo/yolov5/
# !cp 'runs/train/weights/last.pt' /content/drive/MyDrive/yolo/yolov5/

# %%
# !python detect.py --weights runs/train/weights/best.pt --img 512 --conf 0.5 --source '/content/drive/MyDrive/yolo/yolov5/mask.jpg'
# Out:
# detect: weights=['runs/train/weights/best.pt'], source=/content/drive/MyDrive/yolo/yolov5/mask.jpg, data=data/coco128.yaml, imgsz=[512, 512], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-188-g80473a6 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 484 layers, 88397343 parameters, 0 gradients, 219.8 GFLOPs
# image 1/1 /content/drive/MyDrive/yolo/yolov5/mask.jpg: 320x512 5 face masks, Done. (0.055s)
# Speed: 0.9ms pre-process, 55.0ms inference, 1.4ms NMS per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/exp

# %%
# !python detect.py --weights runs/train/weights/best.pt --source 'https://www.youtube.com/watch?v=bHARxN5hSpc'
# Out:
# detect: weights=['runs/train/weights/best.pt'], source=https://www.youtube.com/watch?v=bHARxN5hSpc, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-188-g80473a6 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 484 layers, 88397343 parameters, 0 gradients, 219.8 GFLOPs
# WARNING: Environment does not support cv2.imshow() or PIL Image.show() image displays
# cv2.imshow() is disabled in Google Colab environments
# Traceback (most recent call last):
#   File "detect.py", line 257, in <module>
#     main(opt)
#   File "detect.py", line 252, in main
#     run(**vars(opt))
# ...

# %%
# !cp /content/yolov5/runs/detect/exp2/watch_v_bHARxN5hSpc.mp4 /content/drive/MyDrive/yolo/yolov5/
# Out:
# cp: cannot stat '/content/yolov5/runs/detect/exp2/watch_v_bHARxN5hSpc.mp4': No such file or directory
